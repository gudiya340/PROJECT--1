# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://github.com/dsrscientist/Data-Science-ML-Capstone-Projects/raw/master/baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#checking null values using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Above heatmap show no null values present in given dataset

# %%
# we will find correlation matrix  using the corr()function 
corr_matrix=df.corr()

# %%
plt.figure(1, figsize=(10,5))
sns.heatmap(corr_matrix, cmap= 'BrBG', center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
# Now we will perform  visualization of distribution of continuous features     `

# %%
def qqplot(df,i):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.histplot(x=1,data=df,kde=True)
    plt.subplot(1,3,2)
    sns.regplot(x=i,y='W',data=df)
    plt.subplot(1,3,3)
    sns.boxplot(y=i,data=df)
    plt.show()

# %%
df.columns|()
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
# %matplotlib inline
df.hist(column=['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E'],bins=10, figsize=(20,10))
plt.show()

# %%
# Now we will detect outliers present or not

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (20,15))
# Out:
# W         AxesSubplot(0.125,0.712609;0.133621x0.167391)
# R      AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# AB      AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# H      AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# 2B     AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# 3B        AxesSubplot(0.125,0.511739;0.133621x0.167391)
# HR     AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# BB      AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# SO     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# SB     AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# RA         AxesSubplot(0.125,0.31087;0.133621x0.167391)
# ER      AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# ERA      AxesSubplot(0.44569,0.31087;0.133621x0.167391)
# CG      AxesSubplot(0.606034,0.31087;0.133621x0.167391)
# SHO     AxesSubplot(0.766379,0.31087;0.133621x0.167391)
# SV            AxesSubplot(0.125,0.11;0.133621x0.167391)
# E          AxesSubplot(0.285345,0.11;0.133621x0.167391)
# ...

# %%
#from above plot we find that very less features contains outliers 
#Analysis the outliers by scatter plot

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(x='W',y='SHO',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(x='W',y='R',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(x='W',y='RA',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(x='W',y='ER',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='ER'>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(x='W',y='CG',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
plt.figure(figsize=(12,5),dpi=200)
sns.scatterplot(x='W',y='BB',data=df, size='W')
# Out:
# <AxesSubplot:xlabel='W', ylabel='BB'>

# %%
# Now splitting dataset in testing and training 
from sklearn.model_selection import train_test_split

# %%
x=df.drop(['W'],axis=1)
y=df['W'].values
print(x)
print(y)
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
y
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  81,  80,  78,  88,  86,  85,
#         76,  68, 100,  98,  97,  68,  64,  90,  83,  71,  67,  63,  92,
#         84,  79,  74,  68], dtype=int64)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (24, 16)
# (24,)
# (6, 16)
# (6,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
#y_pred=lr
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
lr.coef_
# Out:
# array([  5.85101972,  -2.15622639,   1.10180853,  -1.10547148,
#          0.16795164,  -0.87806053,  -1.26712814,  -0.12310003,
#         -0.08331406,   4.40271253,  13.66356699, -21.93556552,
#          1.6217774 ,   1.20334265,   5.15820127,  -0.1411542 ])

# %%
lr.intercept_
# Out:
# 80.33333333333331

# %%
lr.predict(x_test)
# Out:
# array([ 82.87055379, 101.01861025,  69.42504558,  93.71375515,
#         91.5547615 ,  79.20277886])

# %%
lr.predict(x)
# Out:
# array([4125.95868385, 4849.98392639, 3456.59726788, 4222.89003985,
#        6333.80525344, 5006.91209172, 4881.58276825, 4790.26090374,
#        3685.17068429, 5641.97820091, 5562.9784709 , 3445.53383402,
#        4352.63239583, 4846.55847764, 4785.47012325, 1437.34906538,
#        2530.97341059, 2720.71132462, 5170.9199623 , 5084.85491867,
#        2885.76528588, 3513.1144397 , 4264.82413672, 5162.33911673,
#        6139.0147648 , 2897.93843801, 3699.32880108, 4804.29664618,
#        4740.09649895, 7598.07308309])

# %%
y_test
# Out:
# array([ 79, 100,  67,  97,  80,  78], dtype=int64)

# %%
lr.score(x_test,y_test)
# Out:
# 0.7876400316149386
